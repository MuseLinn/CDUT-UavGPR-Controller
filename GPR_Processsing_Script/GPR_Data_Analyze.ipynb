# %% [markdown]
# # INFO: Calculate SNR of GPR B-Scan signal(May Changed)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
import csv

from numpy.linalg import eig, inv

plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## Data Injection

# %%
# Read the noise .csv file, Header has 4 lines above the data, so skip the first 4 lines
# Data has 5 columns, 4th column is S21(dBm/dBm), and each data records 201 points(20MHz-170MHz)
# Notice that there is an END string after the last line of data, so we need to skip the last line
# raw_data = np.genfromtxt(r"C:\Users\unive\Desktop\9-9'_csv_[1]_[2]_[3]_[4]_[5]_DATA_out.csv", delimiter=',', skip_header=4, skip_footer=0)
# raw_s21_real = raw_data[:, 3] # sorted as A-Scan_1, A-Scan_2, A-Scan_3, ...

#****************************数据处理后******************************
# NEW DATA format, csv file contains the b-scan array, no headers, has 501 rows(time), unknown columns(A-Scan unit)
# raw_data = np.genfromtxt(r"C:\Users\unive\Desktop\LineL1origin(20)_csv_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)
processed_data = np.genfromtxt(r"C:\Users\unive\Desktop\yaan_main\yaan_main\main_36dbm_11m_csv_[3]_[4]_[5]_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)
processed_data_higher = np.genfromtxt(r"C:\Users\unive\Desktop\yaan_main\yaan_main\main_36dbm_16m_csv_[3]_[4]_[5]_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)
processed_data_red = np.genfromtxt(r"C:\Users\unive\Desktop\yaan_main\yaan_main\mainred_40dbm_11m_csv_[3]_[4]_[5]_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)

# METHOD3:读取一维电磁数据并转换为B-Scan矩阵
def read_csv_bscan_data(file_path):
    """
    读取CSV格式的B-scan数据

    参数:
    file_path: CSV文件路径

    文件格式:
    - 前4行为说明信息
    - 从第5行开始为数据
    - 第4列为电磁数据

    返回:
    b_scan_matrix: B-scan数据矩阵
    """
    # 读取数据，跳过前4行说明信息
    data = pd.read_csv(file_path, skiprows=4, header=None)

    # 提取第4列（索引为3）的电磁数据
    em_data = data.iloc[:, 3].values

    # 将一维数据重塑为B-scan矩阵
    # 需要知道A-scan道数或者时间窗口点数
    # 这里假设您知道其中一个维度，我们可以尝试推断

    return em_data

# bscan_raw_data = read_csv_bscan_data(r"C:\Users\unive\Documents\xwechat_files\wxid_kqjobnjjmucl21_4bec\msg\file\2025-12\mainred_40dbm_11m_csv_[3]_[4]_[5]_DATA_out.csv")

def reshape_to_bscan(em_data, num_time_points=None, num_a_scans=None):
    """
    将一维电磁数据重塑为B-scan矩阵

    参数:
    em_data: 一维电磁数据数组
    num_time_points: 每道A-scan的时间点数（行数）
    num_a_scans: A-scan道数（列数）

    注意：必须提供其中一个参数
    """
    total_points = len(em_data)

    if num_time_points is None and num_a_scans is None:
        # 如果都没提供，尝试找一个合理的因数分解
        # 假设数据是方形或接近方形的
        num_time_points = int(np.sqrt(total_points))
        num_a_scans = total_points // num_time_points

        # 调整以确保乘积等于总点数
        while num_time_points * num_a_scans != total_points:
            if num_time_points * num_a_scans < total_points:
                num_time_points += 1
            else:
                num_a_scans -= 1

        print(f"自动推断矩阵维度: {num_time_points} (时间点) × {num_a_scans} (A-scan道数)")

    elif num_time_points is None:
        num_time_points = total_points // num_a_scans
        if num_time_points * num_a_scans != total_points:
            raise ValueError(f"无法将 {total_points} 个数据点重塑为 {num_time_points} × {num_a_scans} 矩阵")

    elif num_a_scans is None:
        num_a_scans = total_points // num_time_points
        if num_time_points * num_a_scans != total_points:
            raise ValueError(f"无法将 {total_points} 个数据点重塑为 {num_time_points} × {num_a_scans} 矩阵")

    # 重塑数据为B-scan矩阵
    b_scan_matrix = em_data.reshape(num_time_points, num_a_scans)

    return b_scan_matrix

# processed_data = reshape_to_bscan(bscan_raw_data, 501)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       1 # Read the noise .csv file, Header has 4 lines above the data, so skip the first 4 lines
#       2 # Data has 5 columns, 4th column is S21(dBm/dBm), and each data records 201 points(20MHz-170MHz)
#       3 # Notice that there is an END string after the last line of data, so we need to skip the last line
#    (...)
#       8 # NEW DATA format, csv file contains the b-scan array, no headers, has 501 rows(time), unknown columns(A-Scan unit)
#       9 # raw_data = np.genfromtxt(r"C:\Users\unive\Desktop\LineL1origin(20)_csv_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)
# ---> 10 processed_data = np.genfromtxt(r"C:\Users\unive\Desktop\yaan_main\yaan_main\main_36dbm_11m_csv_[3]_[4]_[5]_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)
#      11 processed_data_higher = np.genfromtxt(r"C:\Users\unive\Desktop\yaan_main\yaan_main\main_36dbm_16m_csv_[3]_[4]_[5]_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)
#      12 processed_data_red = np.genfromtxt(r"C:\Users\unive\Desktop\yaan_main\yaan_main\mainred_40dbm_11m_csv_[3]_[4]_[5]_DATA.csv", delimiter=',', skip_header=0, skip_footer=0)
#
# File ~\.conda\envs\magnav\lib\site-packages\numpy\lib\npyio.py:1980, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1978     fname = os_fspath(fname)
#    1979 if isinstance(fname, str):
# -> 1980     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1981     fid_ctx = contextlib.closing(fid)
#    1982 else:
#
# File ~\.conda\envs\magnav\lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~\.conda\envs\magnav\lib\site-packages\numpy\lib\_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: C:\Users\unive\Desktop\yaan_main\yaan_main\main_36dbm_11m_csv_[3]_[4]_[5]_DATA.csv not found.

# %% [markdown]
# ## Function Definition

# %%
# separate the raw_s21_real list into a numpy array(b_scan matrix, the row axis is time, the column axis is A-Scan unit)
# raw_s21_real format is [A-Scan_1, A-Scan_2, A-Scan_3, ...], each A-Scan has 501 points(from 0-700ns)
# b_scan = np.array(raw_s21_real).reshape(501, -1)
# print the dimension of b_scan to check the row&col is right
# print(b_scan.shape)

# TODO: CHECK the algorithm after our project finished
# 1. time-index conversion
def time_to_point(time, start_time, end_time, ascan_points):
    """
    Calculate the mapping relationship between "time and row index"
    Time unit: ns
    """
    time_range = end_time - start_time
    point_converted = int(time / time_range * ascan_points)
    # print(f"time: {time}, mapped to point: {point_converted}")
    return point_converted

def point_to_time(point, start_time, end_time, ascan_points):
    """
    Calculate the mapping relationship between "point and time"
    Time unit: ns
    """
    time_range = end_time - start_time
    time_converted = point / ascan_points * time_range
    # print(f"point: {point}, mapped to time: {time_converted}")
    return time_converted

#***************************B-Scan成像******************************
def BScan_plot(b_scan, time_start=0, time_end=700, title='B-Scan Grayscale Plot', annotations=None):
    """
    绘制B-Scan图像的通用函数，并可选择性地添加标注区域

    参数:
    b_scan: numpy数组，B-Scan数据矩阵
    time_start: 起始时间(ns)，默认0
    time_end: 结束时间(ns)，默认700
    title: 图像标题，默认'B-Scan Grayscale Plot'
    annotations: 可选，一个包含标注信息的列表，每个元素为字典:
                 {'time_range': (start_time, end_time), 'scan_range': (start_scan, end_scan), 'color': 'color', 'label': 'label'}
    """
    # 计算时间和扫描范围
    time_points = b_scan.shape[0]
    time_range = np.linspace(time_start, time_end, time_points)
    scan_range = np.arange(1, b_scan.shape[1] + 1)

    # 创建图像
    fig, ax = plt.subplots(figsize=(10, 6))
    im = ax.imshow(b_scan, cmap='gray', aspect='auto',
                   extent=[scan_range[0], scan_range[-1], time_range[-1], time_range[0]])

    # 设置坐标轴
    ax.set_xlabel('A-Scan Unit')
    ax.set_ylabel('Time (ns)')
    ax.set_title(title)
    plt.colorbar(im, ax=ax)

    # 添加标注区域
    if annotations:
        for ann in annotations:
            time_range_ann = ann['time_range']
            scan_range_ann = ann['scan_range']
            color = ann.get('color', 'red')
            label = ann.get('label', '')

            # 处理time_range为None的情况（使用整个时间轴范围）
            if time_range_ann is None:
                time_range_ann = (time_start, time_end)

            # 处理scan_range为None的情况（使用整个A-Scan范围）
            if scan_range_ann is None:
                scan_range_ann = (scan_range[0], scan_range[-1])

            # 计算矩形的左下角坐标和宽度、高度
            x = scan_range_ann[0]
            y = time_range_ann[0]
            width = scan_range_ann[1] - scan_range_ann[0]
            height = time_range_ann[1] - time_range_ann[0]

            # 创建并添加矩形
            rect = patches.Rectangle((x, y), width, height, linewidth=2, edgecolor=color, facecolor='none', label=label)
            ax.add_patch(rect)

            # 添加标签
            if label:
                ax.text(x, y, label, color=color, fontsize=10,
                    verticalalignment='bottom', horizontalalignment='left',
                    bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.7))

    # plt.show(block=False)  # 非阻塞显示
    return ax  # 返回轴对象，以便外部可以进一步操作

# 使用示例：
# BScan_plot(raw_data, 0, 700, 'Original B-Scan')
# BScan_plot(b_scan_power, 0, 700, 'B-Scan Power Plot')
# BScan_plot(X_prime_real, 0, 700, 'SGC-Preprocessed B-Scan')

def annotate_bscan_region(ax, time_range=None, scan_range=None, color='red', linewidth=2, label=None):
    """
    在B-Scan图像上标注特定区域

    参数:
    ax: matplotlib轴对象
    time_range: 时间范围元组 (start_time, end_time)，默认None（自动获取图像y轴范围）
    scan_range: A-Scan范围元组 (start_scan, end_scan)，默认None（自动获取图像x轴范围）
    color: 边框颜色，默认为红色
    linewidth: 边框线宽
    label: 标签文本
    """
    # 如果未提供time_range，使用图像y轴的完整范围
    if time_range is None:
        y_lim = ax.get_ylim()
        time_range = (y_lim[1], y_lim[0])  # 注意imshow的y轴方向

    # 如果未提供scan_range，使用图像x轴的完整范围
    if scan_range is None:
        x_lim = ax.get_xlim()
        scan_range = (x_lim[0], x_lim[1])

    # 获取区域坐标
    x_start, x_end = scan_range
    y_start, y_end = time_range

    # 绘制矩形框
    from matplotlib.patches import Rectangle
    rect = Rectangle((x_start, y_start), x_end - x_start, y_end - y_start,
                     linewidth=linewidth, edgecolor=color, facecolor='none', label=label)
    ax.add_patch(rect)

    # 添加标签（如果提供）
    if label:
        ax.text(x_start, y_start, label, color=color, fontsize=10,
                verticalalignment='bottom', horizontalalignment='left',
                bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.7))


# 使用示例：
# 假设你已经有了B-Scan图像的轴对象ax
# annotate_bscan_region(ax, (100, 200), (500, 1000), color='yellow', label='Noise Region')
# annotate_bscan_region(ax, (400, 500), (1200, 1800), color='blue', label='Target Region')

#******************************SNR计算(均值)******************************
def calculate_SNR(b_scan_power, noise_time_range, target_time_range, time_params=(0, 700, 501)):
    """
        计算B-Scan数据的信噪比(SNR)

        参数:
        b_scan_power: numpy数组，B-Scan功率数据矩阵
        noise_time_range: 元组，噪声区域时间范围(start, end)，例如(100, 200)
        target_time_range: 元组，目标区域时间范围(start, end)，例如(400, 500)
        time_params: 元组，时间参数(start_time, end_time, ascan_points)，默认(0, 700, 501)

        返回:
        SNR_dB: float，信噪比(dB)
        SNR_linear: float，信噪比(线性)
        """
    start_time, end_time, ascan_points = time_params

    # 提取噪声区域数据
    noise_start = time_to_point(noise_time_range[0], start_time, end_time, ascan_points)
    noise_end = time_to_point(noise_time_range[1], start_time, end_time, ascan_points)
    noise_power = b_scan_power[noise_start:noise_end]

    # 提取目标区域数据
    target_start = time_to_point(target_time_range[0], start_time, end_time, ascan_points)
    target_end = time_to_point(target_time_range[1], start_time, end_time, ascan_points)
    target_power = b_scan_power[target_start:target_end]

    # 计算平均功率
    noise_mean = noise_power.mean()
    target_mean = target_power.mean()

    # 计算SNR
    # signal_eff = target_mean - noise_mean
    signal_eff = target_mean
    SNR_linear = signal_eff / noise_mean
    SNR_dB = 10 * np.log10(SNR_linear)

    print(f"noise mean: {noise_mean}")
    print(f"target mean: {target_mean}")
    print(f"signal_effective: {signal_eff}")
    print(f"SNR_linear: {SNR_linear}, SNR_dB: {SNR_dB}")

    return SNR_dB, SNR_linear

# TCR目标杂波比 20lg_10((1/N_T * \sum (p,q)属于T |X(p,q)|^2)/(1/N_C * \sum (p,q)属于C |X(p,q)|^2))
#*****************************TCR计算******************************
def calculate_TCR(b_scan, noise_time_range, target_time_range, time_params=(0, 700, 501)):
    """
    计算探地雷达（GPR）B-Scan数据的目标杂波比（TCR）
    计算公式参考文档：TCR(dB) = 20*log10(目标区域平均功率 / 杂波区域平均功率)

    参数：
    b_scan: np.array，形状为(501, 2383)的B-Scan矩阵，行对应0-700ns，列对应2383个A-Scan
    noise_time_range: 元组，噪声区域时间范围(start, end)，例如(100, 200)
    target_time_range: 元组，目标区域时间范围(start, end)，例如(400, 500)
    time_params: 元组，时间参数(start_time, end_time, ascan_points)，默认(0, 700, 501)

    返回：
    tcr_db: float，TCR值（单位：dB）
    """
    start_time, end_time, ascan_points = time_params

    # 1. 定义杂波区域：使用传入的noise_time_range参数
    clutter_row_start = time_to_point(noise_time_range[0], start_time, end_time, ascan_points)
    clutter_row_end = time_to_point(noise_time_range[1], start_time, end_time, ascan_points)
    # 提取杂波区域数据：所有列的杂波行
    clutter_region = b_scan[clutter_row_start:clutter_row_end + 1, :]

    # 2. 定义目标区域：使用传入的target_time_range参数
    target_row_start = time_to_point(target_time_range[0], start_time, end_time, ascan_points)
    target_row_end = time_to_point(target_time_range[1], start_time, end_time, ascan_points)
    # 提取目标区域数据：所有列的目标行
    target_region = b_scan[target_row_start:target_row_end + 1, :]

    # 3. 计算目标区域平均功率（像素强度平方的均值）
    # 文档定义：目标区域平均功率 = (1/N_T) * Σ|X(p,q)|²，其中N_T为目标区域像素数
    target_power = np.mean(np.square(np.abs(target_region)))
    N_T = target_region.size  # 目标区域总像素数（行数×列数）

    # 4. 计算杂波区域平均功率
    # 文档定义：杂波区域平均功率 = (1/N_C) * Σ|X(p,q)|²，其中N_C为杂波区域像素数
    clutter_power = np.mean(np.square(np.abs(clutter_region)))
    N_C = clutter_region.size  # 杂波区域总像素数

    # 5. 计算TCR（避免除以零，添加微小值）
    epsilon = 1e-10  # 防止杂波功率为0导致计算错误
    tcr_db = 20 * np.log10((target_power + epsilon) / (clutter_power + epsilon))

    return tcr_db

# %% [markdown]
# ## Data Processing

# %%
# S21 Real（网络参数实部）是 “电压传输系数的实部”（幅度维度，可正可负），而非 “功率比值”，直接按之前的功率比逻辑计算会因 “负值 / 零值” 导致对数转换出现 NaN。
# b_scan_power = raw_data ** 2
b_scan_proc_power = processed_data ** 2
b_scan_proc_power_higher = processed_data_higher ** 2
b_scan_proc_power_red = processed_data_red ** 2

# 定义标注区域
annotations = [
    # {
    #     'time_range': (120, 200),
    #     'scan_range': None,
    #     'color': 'yellow',
    #     'label': 'Noise Region'
    # },
    {
        'time_range': (400, 560), #350 500
        'scan_range': None,
        'color': 'red',
        'label': 'Target Region'
    }
]

annotations1 = [
    # {
    #     'time_range': (120, 200),
    #     'scan_range': None,
    #     'color': 'yellow',
    #     'label': 'Noise Region'
    # },
    {
        'time_range': (370, 530), #350 500
        'scan_range': None,
        'color': 'red',
        'label': 'Target Region'
    }
]

# # 调用修改后的函数
# BScan_plot(raw_data, 0, 700, 'Original B-Scan with Annotations', annotations)

# draw the b_scan grayscale plot to check the data
# ax = BScan_plot(raw_data, 0, 900, 'Original B-Scan', annotations)
# annotate_bscan_region(ax, None, (500, 1000), color='yellow', label='Noise Region')
# plt.show()
# BScan_plot(b_scan_power, 0, 900, 'Orignial B-Scan Power Plot', annotations)
# plt.show()
BScan_plot(processed_data, 0, 900, 'Processed B-Scan of 21 line', annotations)
plt.savefig(r"C:\Users\unive\Desktop\yaan_main\21号测线处理后的b_scan(0, 60)_(400, 560).png")
plt.show()
BScan_plot(b_scan_proc_power, 0, 900, 'Processed B-Scan Power Plot', annotations)
plt.savefig(r"C:\Users\unive\Desktop\yaan_main\21号测线处理后的b_scan功率(0, 60)_(400, 560).png")
plt.show()

BScan_plot(processed_data, 0, 900, 'Processed B-Scan of 21 line', annotations)
plt.savefig(r"C:\Users\unive\Desktop\yaan_main\21号测线处理后的b_scan(0, 60)_(370, 530)higher.png")
plt.show()
BScan_plot(b_scan_proc_power, 0, 900, 'Processed B-Scan Power Plot', annotations)
plt.savefig(r"C:\Users\unive\Desktop\yaan_main\21号测线处理后的b_scan功率(0, 60)_(370, 530)higher.png")
plt.show()

BScan_plot(processed_data, 0, 900, 'Processed B-Scan of 21 line', annotations)
plt.savefig(r"C:\Users\unive\Desktop\yaan_main\21_red的b_scan(0, 60)_(400, 560).png")
plt.show()
BScan_plot(b_scan_proc_power, 0, 900, 'Processed B-Scan Power Plot', annotations)
plt.savefig(r"C:\Users\unive\Desktop\yaan_main\21_red的b_scan功率(0, 60)_(400, 560).png")
plt.show()
# Out:
# <Axes: title={'center': 'Processed B-Scan of 21 line'}, xlabel='A-Scan Unit', ylabel='Time (ns)'>
# <Axes: title={'center': 'Processed B-Scan Power Plot'}, xlabel='A-Scan Unit', ylabel='Time (ns)'>
# <Axes: title={'center': 'Processed B-Scan of 21 line'}, xlabel='A-Scan Unit', ylabel='Time (ns)'>
# <Axes: title={'center': 'Processed B-Scan Power Plot'}, xlabel='A-Scan Unit', ylabel='Time (ns)'>
# <Axes: title={'center': 'Processed B-Scan of 21 line'}, xlabel='A-Scan Unit', ylabel='Time (ns)'>
# <Axes: title={'center': 'Processed B-Scan Power Plot'}, xlabel='A-Scan Unit', ylabel='Time (ns)'>

# %%
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = 'all'

# 使用示例：
# SNR_dB, SNR_linear = calculate_SNR(b_scan_power, (120, 200), (400, 500))
# print("原始数据结果：")
# SNR_dB1, SNR_linear1 = calculate_SNR(b_scan_power, (120, 200), (360, 480)) #line9
# raw_data_tcr_result = calculate_TCR(raw_data, (120, 200), (360, 480))
# print(f"原始数据TCR值：{raw_data_tcr_result:.2f} dB")

print("------21 main------")
# print("处理后的结果：")
SNR_dB2, SNR_linear2 = calculate_SNR(b_scan_proc_power, (0, 60), (400, 560))
processed_data_tcr_result = calculate_TCR(processed_data, (0, 60), (400, 560))
print(f"处理后的TCR值：{processed_data_tcr_result:.2f} dB")

print("------21 higher------")
# print("处理后的结果：")
SNR_dB2, SNR_linear2 = calculate_SNR(b_scan_proc_power_higher, (0, 60), (370, 530))
processed_data_tcr_result = calculate_TCR(processed_data_higher, (0, 60), (370, 530))
print(f"处理后的TCR值：{processed_data_tcr_result:.2f} dB")

print("------21 red------")
# print("处理后的结果：")
SNR_dB2, SNR_linear2 = calculate_SNR(b_scan_proc_power_red, (0, 60), (400, 560))
processed_data_tcr_result = calculate_TCR(processed_data_red, (0, 60), (400, 560))
print(f"处理后的TCR值：{processed_data_tcr_result:.2f} dB")
# Out:
# ------21 main------
# noise mean: 0.0017650572042327874
# target mean: 0.02545761360325514
# signal_effective: 0.02545761360325514
# SNR_linear: 14.423109654579571, SNR_dB: 11.590589053368108
# 处理后的TCR值：22.72 dB
# ------21 higher------
# noise mean: 0.001661970506033017
# target mean: 0.027511356337860025
# signal_effective: 0.027511356337860025
# SNR_linear: 16.55345641694166, SNR_dB: 12.188886897175609
# 处理后的TCR值：24.12 dB
# ------21 red------
# noise mean: 0.0020316107687390413
# target mean: 0.0297991270794713
# signal_effective: 0.0297991270794713
# SNR_linear: 14.667734360340445, SNR_dB: 11.663630360797445
# 处理后的TCR值：22.99 dB

# %% [markdown]
# # DEPRECATED
# ### SGC增益论文复现测试

# %%
# 1. 输入B-scan矩阵X（你的数据）
X = raw_data  # 维度：(m=501, n=2383)
m, n = X.shape

# 2. 计算X_sym = X^T · X（步骤1 of Algorithm 1）
X_sym = X.T @ X  # 维度：(n=2383, n=2383)

# 3. 求解X_sym的特征值λ_i和右特征向量v_i（步骤2 of Algorithm 1）
# 注：X^T X的特征值=X的奇异值²，右特征向量=X的右奇异向量V
eigenvalues, V = eig(X_sym)  # eigenvalues: (2383,), V: (2383, 2383)

# 4. 对特征值按降序排序，同步调整右特征向量（步骤3 of Algorithm 1）
sorted_idx = np.argsort(eigenvalues)[::-1]  # 从大到小排序的索引
sorted_lambda = eigenvalues[sorted_idx]     # 排序后的特征值
V_sorted = V[:, sorted_idx]                 # 排序后的右奇异向量V

# 5. 计算奇异值σ_i = √λ_i，构造对角矩阵Σ（步骤4-5 of Algorithm 1）
k_n = min(m, n)  # 奇异值总数：min(501,2383)=501（论文中k_n定义）
sigma = np.sqrt(sorted_lambda[:k_n])  # 取前k_n个特征值的平方根（避免冗余）
Sigma = np.diag(sigma)                # 对角矩阵Σ：(k_n=501, k_n=501)

# 6. 计算左奇异向量U = X · V_sorted[:,:k_n] · Σ⁻¹（步骤7 of Algorithm 1）
# 仅取V_sorted的前k_n列（与Σ维度匹配），Σ⁻¹为对角矩阵的逆（元素=1/σ_i）
V_k = V_sorted[:, :k_n]  # (2383, 501)
Sigma_inv = inv(Sigma)   # (501, 501)
U = X @ V_k @ Sigma_inv  # 左奇异向量U：(501, 501)

# 7. 构造权重矩阵W（公式6，步骤8 of Algorithm 1）
# W维度：(1, k_n=501)，元素为[1, (1-1/k_n), (1-2/k_n), ..., 1/k_n]
w_values = np.array([1 - i/k_n for i in range(k_n)])  # 长度501的权重序列
# 8. 转换为对角矩阵（501×501），确保与U、Sigma维度适配
W_diag = np.diag(w_values)  # 修正后：W_diag维度(501,501)

# 重新计算噪声抑制项term（维度匹配）
# U(501×501) @ W_diag(501×501) → 501×501
# 再 @ Sigma(501×501) → 501×501
# 再 @ V_k.T(501×2383) → 501×2383（与X维度一致）
term = U @ W_diag @ Sigma @ V_k.T  # 修正后无维度错误
X_prime = X - term  # SGC预处理结果（501×2383）
print(f"X_prime shape:{X_prime.shape}")

freq_points = 501  # 行数量（频点）
time_window = 700  # 总时窗（ns）
time_axis = np.linspace(0, time_window, freq_points)  # 纵轴时间值：[0, 700]ns，共501个点
ascan_axis = np.arange(X_prime.shape[1])  # 横轴A-Scan道数：0~2837
# 创建画布（论文中图像为单幅或多幅对比，此处以单幅SGC结果为例）
fig, ax = plt.subplots(figsize=(12, 6))  # 宽=12（适配2838道A-Scan），高=6（适配501个频点）

# 绘制B-Scan热力图：extent参数定义坐标轴范围（左,右,下,上）
# 注意：matplotlib的imshow默认“行=纵轴”，需将时间轴作为纵轴，且原点在下方（符合“时间从0开始向上递增”）
# 关键修正：将复数B-scan转换为实数值（取信号幅值）
X_prime_real = np.abs(X_prime)  # 此时X_prime_real为float64类型，符合imshow要求
print(X_prime_real.dtype)  # 输出应为float64或float32，确保无complex类型
# 后续绘制用X_prime_real替代X_prime
im = ax.imshow(
    np.flipud(X_prime_real),
    extent=[ascan_axis[0], ascan_axis[-1], time_axis[-1], time_axis[0]],
    origin='lower',
    cmap='gray',
    aspect='auto'
)

# 添加颜色条：标注“信号强度”（论文中颜色条为可选，用于说明颜色与信号的对应关系）
cbar = fig.colorbar(im, ax=ax, shrink=0.8)
cbar.set_label('Signal Intensity (a.u.)', fontsize=10)  # a.u.=任意单位，符合GPR信号幅值表述
# 坐标轴标签（论文中纵轴为“时间”，横轴为“A-Scan道数”）
ax.set_ylabel('A-Scan Channel', fontsize=11)  # 横轴：A-Scan道数（空间维度）
ax.set_xlabel('Time (ns)', fontsize=11)       # 纵轴：时间（ns，对应频点转换后的时窗）

# 标题（论文中标题需说明“预处理方法”，如Fig.6(c)标注“SGC”）
ax.set_title('SGC-Preprocessed GPR B-Scan', fontsize=12, fontweight='bold')

# 调整布局（避免标签被截断）
plt.tight_layout()

# 保存图像（论文中图像为高清格式，如PDF或PNG，分辨率300dpi）
# plt.savefig('SGC_BScan.png', dpi=300, bbox_inches='tight')
plt.show()  # 非阻塞显示

X_prime_real_power = X_prime_real **2
BScan_plot(X_prime_real_power, 0, 700, 'SGC-Preprocessed GPR B-Scan')

SNR_dB, SNR_linear = calculate_SNR(X_prime_real_power, (100, 200), (400, 500))

# # 取其中一道A-Scan的一段时间作为噪声信号，完整A-Scan数据作为信号，计算这个信噪比
# a_scan_data = raw_data[:, 1300]
# a_scan_noise = a_scan_data[time_to_point(400, 0, 700, 501):time_to_point(500, 0, 700, 501)]
# a_scan_signal = a_scan_data
# SNR_linear = a_scan_signal.mean() / a_scan_noise.mean()
# SNR_dB = 10 * np.log10(SNR_linear)
# print(f"A-Scan SNR_linear: {SNR_linear}, SNR_dB: {SNR_dB}")

# %% [markdown]
# ## Deprecated

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. 创建一个模拟的BScan数据矩阵 (128x128)
# 这里我们用一些正弦波来模拟周期性信号，叠加一些噪声
height, width = 128, 128
x = np.linspace(0, 2*np.pi, width)
y = np.linspace(0, 2*np.pi, height)
xx, yy = np.meshgrid(x, y)

# 模拟信号：两个不同频率的正弦波叠加
signal = np.sin(4 * xx) + np.cos(6 * yy)
# 添加噪声
bscan_data = signal + 0.5 * np.random.randn(height, width)

# 2. 数据预处理：去除直流分量
bscan_data = bscan_data - np.mean(bscan_data)

# 3. 计算二维傅里叶变换
fft_result = np.fft.fft2(bscan_data)

# 4. 计算功率谱密度 (PSD)
psd = np.abs(fft_result) ** 2

# 5. 中心化处理
psd_centered = np.fft.fftshift(psd)

# 6. 可视化结果
plt.figure(figsize=(12, 6))

# 显示原始BScan数据
plt.subplot(1, 2, 1)
plt.imshow(bscan_data, cmap='gray')
plt.title('Original BScan Data')
plt.colorbar()

# 显示功率谱 (通常用对数尺度以更好地显示细节)
plt.subplot(1, 2, 2)
plt.imshow(np.log10(psd_centered + 1e-6), cmap='viridis')
plt.title('Power Spectral Density (PSD)')
plt.colorbar()

plt.tight_layout()
plt.show()

# %%
import numpy as np

# 原始图像
I = np.array([[1, 2, 3],
              [3, 4, 5],
              [5, 6, 7]], dtype=np.float64)

# 方法1：手动分行列做一维FFT
row_fft = np.fft.fft(I, axis=1)  # 对每一行做FFT
col_fft = np.fft.fft(row_fft, axis=0)  # 对行FFT结果的每一列做FFT

# 方法2：直接用二维FFT
fft2_result = np.fft.fft2(I)

print("手动分行列计算结果：\n", col_fft)
print("\n直接二维FFT结果：\n", fft2_result)

# 逆变换验证数据是否一致
inverse_result = np.fft.ifft2(fft2_result)
print("\n逆变换结果：\n", inverse_result)
# Out:
# 手动分行列计算结果：
#  [[36. +0.j         -4.5+2.59807621j -4.5-2.59807621j]
#  [-9. +5.19615242j  0. +0.j          0. +0.j        ]
#  [-9. -5.19615242j  0. +0.j          0. +0.j        ]]
#
# 直接二维FFT结果：
#  [[36. +0.j         -4.5+2.59807621j -4.5-2.59807621j]
#  [-9. +5.19615242j  0. +0.j          0. +0.j        ]
#  [-9. -5.19615242j  0. +0.j          0. +0.j        ]]
#
# 逆变换结果：
#  [[1.+0.j 2.+0.j 3.+0.j]
#  [3.+0.j 4.+0.j 5.+0.j]
#  [5.+0.j 6.+0.j 7.+0.j]]

# %% [markdown]
# # PreProcessed CSV File Quantity Statistics

# %%
import os

def get_csv_all_rows(file_path):
    """读取CSV文件的完整行数（包含表头，统计真实行数）"""
    encodings = ['utf-8', 'gbk', 'utf-8-sig']  # 覆盖常见的CSV文件编码
    for enc in encodings:
        try:
            with open(file_path, 'r', encoding=enc) as f:
                # 逐行统计，高效且不占用大量内存
                row_count = sum(1 for _ in f)
                return row_count
        except (UnicodeDecodeError, FileNotFoundError):
            continue
    print(f"⚠️ 无法读取文件（编码不兼容/文件不存在）：{file_path}")
    return 0

def count_csv_rows_by_folder(parent_dir, target_folders):
    """
    统计指定文件夹下所有CSV的行数
    返回：总计行数、各文件夹行数字典
    """
    total_rows = 0
    folder_row_dict = {}  # 存储每个文件夹的总行数

    # 遍历每个目标文件夹
    for folder_name in target_folders:
        folder_path = os.path.join(parent_dir, folder_name)
        folder_total = 0  # 单个文件夹的总行数

        if not os.path.exists(folder_path):
            print(f"⚠️ 文件夹不存在，已跳过：{folder_path}")
            folder_row_dict[folder_name] = 0
            continue

        # 递归遍历文件夹内所有CSV文件
        for root, _, files in os.walk(folder_path):
            for file in files:
                if file.lower().endswith(".csv"):
                    file_path = os.path.join(root, file)
                    rows = get_csv_all_rows(file_path)
                    folder_total += rows
                    total_rows += rows
                    print(f"✅ {file_path} → 行数：{rows}")

        # 记录当前文件夹的总行数
        folder_row_dict[folder_name] = folder_total
        print(f"\n📁 文件夹「{folder_name}」总计行数：{folder_total}\n" + "-"*60)

    return total_rows, folder_row_dict

if __name__ == "__main__":
    # -------------------------- 请修改以下配置 --------------------------
    # 1. 填写存放所有实验数据文件夹的父目录路径（绝对路径）
    # 示例：PARENT_DIR = r"D:\实验数据\2025采集数据"
    PARENT_DIR = r"F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据"

    # 2. 填写需要统计的所有实验数据文件夹名称
    TARGET_FOLDERS = [
        "安徽省黄山市和平村滑坡应用示范采集数据",
        "甘肃省兰州市皋兰山应用示范采集数据",
        "四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据",
        "四川省雅安市宝兴县陇东镇滑坡应用示范采集数据",
        "浙江省丽水市庆元县淤上村滑坡应用示范采集数据",
        "浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据"
    ]
    # ----------------------------------------------------------------------

    # 执行统计
    total_rows, folder_stats = count_csv_rows_by_folder(PARENT_DIR, TARGET_FOLDERS)

    # 输出最终汇总结果
    print("\n" + "="*80)
    print("📊 各文件夹CSV行数汇总：")
    print("-"*80)
    for folder_name, row_count in folder_stats.items():
        print(f"🔹 {folder_name}：{row_count} 行")
    print("-"*80)
    print(f"🎯 所有CSV文件的完整真实总行数：{total_rows}")
    print("="*80)
# Out:
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N9测线标准格式数据_20250920_102915.csv → 行数：23262
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N1测线标准格式数据_20250920_102915.csv → 行数：25267
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N8测线标准格式数据_20250920_102915.csv → 行数：24866
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N12测线标准格式数据_20250920_102915.csv → 行数：28475
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N10测线标准格式数据_20250920_102915.csv → 行数：27272
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\L2测线标准格式数据_20250920_102915.csv → 行数：78199
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N7测线标准格式数据_20250920_102915.csv → 行数：32886
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N13测线标准格式数据_20250920_102915.csv → 行数：28876
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N2测线标准格式数据_20250920_102915.csv → 行数：20054
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N5测线标准格式数据_20250920_102915.csv → 行数：43713
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\L3测线标准格式数据_20250920_102915.csv → 行数：76194
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N6测线标准格式数据_20250920_102915.csv → 行数：44916
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N3测线标准格式数据_20250920_102915.csv → 行数：22059
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N4测线标准格式数据_20250920_102915.csv → 行数：41708
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\N11测线标准格式数据_20250920_102915.csv → 行数：30881
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\安徽省黄山市和平村滑坡应用示范采集数据\L1测线标准格式数据(1).csv → 行数：84214
#
# 📁 文件夹「安徽省黄山市和平村滑坡应用示范采集数据」总计行数：632842
# ------------------------------------------------------------
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-x4标准格式数据.csv → 行数：136344
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-x1标准格式数据.csv → 行数：116294
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-x1标准格式数据.csv → 行数：119101
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-x3标准格式数据.csv → 行数：126319
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-x6标准格式数据.csv → 行数：121507
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-y6标准格式数据.csv → 行数：97848
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-x2标准格式数据.csv → 行数：119101
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-y2标准格式数据.csv → 行数：154790
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-y1标准格式数据.csv → 行数：165617
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\6-x1标准格式数据.csv → 行数：43312
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\6-y1标准格式数据.csv → 行数：58951
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-y5标准格式数据.csv → 行数：138750
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-y3标准格式数据.csv → 行数：155993
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-x7标准格式数据.csv → 行数：90630
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-x5标准格式数据.csv → 行数：121507
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-x2标准格式数据.csv → 行数：120705
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-x3标准格式数据.csv → 行数：129928
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\6-y2标准格式数据.csv → 行数：146770
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-x6标准格式数据.csv → 行数：128324
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-x5标准格式数据.csv → 行数：123913
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-x4标准格式数据.csv → 行数：132735
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-y4标准格式数据.csv → 行数：126319
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-y2标准格式数据.csv → 行数：139552
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\9-y1标准格式数据.csv → 行数：121106
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-y1标准格式数据.csv → 行数：143161
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-y5标准格式数据.csv → 行数：131933
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\7-y3标准格式数据.csv → 行数：144765
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\甘肃省兰州市皋兰山应用示范采集数据\3-y4标准格式数据.csv → 行数：190479
#
# 📁 文件夹「甘肃省兰州市皋兰山应用示范采集数据」总计行数：3545754
# ------------------------------------------------------------
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line3origin(36).csv → 行数：908317
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\LineL1origin(20).csv → 行数：989980
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\LineL1origin(30).csv → 行数：1005511
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line3origin(20).csv → 行数：987475
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line7origin(36).csv → 行数：828658
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line6origin(20).csv → 行数：474952
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\LineX1origin(20).csv → 行数：449902
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line6origin(30).csv → 行数：822646
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line7origin(30).csv → 行数：958918
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\LineL1origin(36).csv → 行数：976954
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\LineX1origin(30).csv → 行数：453409
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line3origin(30).csv → 行数：921844
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line6origin(36).csv → 行数：832165
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\LineX1origin(36).csv → 行数：469942
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line7origin(20).csv → 行数：959920
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line9origin(30).csv → 行数：1193887
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line9origin(36).csv → 行数：1191382
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据\Line9origin(20).csv → 行数：1283065
#
# 📁 文件夹「四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据」总计行数：15708927
# ------------------------------------------------------------
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线wd6-2_功率33dbm.csv → 行数：1261021
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-1_功率36dbm_高度11m.csv → 行数：1420840
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-1_功率30dbm_高度16m.csv → 行数：1440880
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线wd6-3_功率33dbm.csv → 行数：1205911
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-2_功率36dbm_高度11m.csv → 行数：1432363
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线main_功率36dbm_高度16m.csv → 行数：1455910
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线wd6-1_功率33dbm.csv → 行数：1179358
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-2_功率30dbm_高度16m.csv → 行数：1432363
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-1_功率36dbm_高度16m.csv → 行数：1450900
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-2_功率36dbm_高度16m.csv → 行数：1437373
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线main_功率36dbm_高度11m.csv → 行数：1412323
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-2_功率30dbm_高度11m.csv → 行数：1526050
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\mainred_40dbm_11m.csv → 行数：1430359
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线21-1_功率30dbm_高度11m.csv → 行数：1543585
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线main_功率30dbm_高度16m.csv → 行数：1436371
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\四川省雅安市宝兴县陇东镇滑坡应用示范采集数据\测线main_功率30dbm_高度11m.csv → 行数：1903303
#
# 📁 文件夹「四川省雅安市宝兴县陇东镇滑坡应用示范采集数据」总计行数：22968910
# ------------------------------------------------------------
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x1.csv → 行数：41307
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x7.csv → 行数：57347
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x6.csv → 行数：84615
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y2.csv → 行数：83412
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x2.csv → 行数：82209
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x5.csv → 行数：81808
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x4.csv → 行数：84615
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y12.csv → 行数：86219
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y1.csv → 行数：62560
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y34.csv → 行数：64966
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y20.csv → 行数：84615
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x3.csv → 行数：84615
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y28.csv → 行数：137547
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y29.csv → 行数：144364
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y35.csv → 行数：62159
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\x8.csv → 行数：50931
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y33.csv → 行数：87021
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y10.csv → 行数：178048
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y11.csv → 行数：199301
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y19.csv → 行数：150780
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y3.csv → 行数：142359
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y18.csv → 行数：191281
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y26.csv → 行数：202910
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y42.csv → 行数：105868
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y13.csv → 行数：216544
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y14.csv → 行数：226168
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y15.csv → 行数：216143
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y30.csv → 行数：153186
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y16.csv → 行数：217346
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y31.csv → 行数：149978
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y17.csv → 行数：207722
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y32.csv → 行数：159602
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y39.csv → 行数：139552
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y41.csv → 行数：122710
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y37.csv → 行数：152384
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym12.csv → 行数：110680
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y38.csv → 行数：144765
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym13.csv → 行数：101457
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y40.csv → 行数：151181
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y27.csv → 行数：245817
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y36.csv → 行数：180053
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y4.csv → 行数：173637
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y7.csv → 行数：201306
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y9.csv → 行数：207321
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y6.csv → 行数：206519
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym1.csv → 行数：210930
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y8.csv → 行数：204514
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym5.csv → 行数：225366
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym3.csv → 行数：214940
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym2.csv → 行数：225767
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym6.csv → 行数：230178
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\y5.csv → 行数：268273
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym7.csv → 行数：240604
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市庆元县淤上村滑坡应用示范采集数据\ym4.csv → 行数：232985
#
# 📁 文件夹「浙江省丽水市庆元县淤上村滑坡应用示范采集数据」总计行数：8288485
# ------------------------------------------------------------
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A4-NEW-1.csv → 行数：68890
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A3-NEW-1.csv → 行数：78502
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B7-NEW-1.csv → 行数：44860
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C10-NEW-1.csv → 行数：72895
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A8-NEW-1.csv → 行数：63283
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A10-NEW-1.csv → 行数：67288
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A7-NEW-1.csv → 行数：64084
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B8-NEW-1.csv → 行数：47263
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A9-NEW-1.csv → 行数：60880
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B9-NEW-1.csv → 行数：53671
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B6-NEW-1.csv → 行数：52069
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B10-NEW-1.csv → 行数：52069
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A5-NEW-1.csv → 行数：102532
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A1-NEW-1.csv → 行数：73696
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B5-NEW-1.csv → 行数：52870
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A2-NEW-1.csv → 行数：68089
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\A6-NEW-1.csv → 行数：96925
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C7-NEW-1.csv → 行数：89716
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C8-NEW-1.csv → 行数：91318
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C6-NEW-1.csv → 行数：126562
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B3-NEW-1.csv → 行数：177025
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C5-NEW-1.csv → 行数：129766
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B2-NEW-1.csv → 行数：196249
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\B4-NEW-1.csv → 行数：199453
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C9-NEW-1.csv → 行数：69691
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C4-NEW-1.csv → 行数：205060
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C2-NEW-1.csv → 行数：219478
# ✅ F:\课题二软硬件部分-202512-21世纪数据中心数据汇交材料\2022YFC3003200\02\2022YFC3003200_D_1\航空探地雷达工程样机的示范区（滑坡实验区）采集数据\浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据\C3-NEW-1.csv → 行数：211468
#
# 📁 文件夹「浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据」总计行数：2835652
# ------------------------------------------------------------
#
# ================================================================================
# 📊 各文件夹CSV行数汇总：
# --------------------------------------------------------------------------------
# 🔹 安徽省黄山市和平村滑坡应用示范采集数据：632842 行
# 🔹 甘肃省兰州市皋兰山应用示范采集数据：3545754 行
# 🔹 四川省南充市营山县消水镇大秧坪滑坡（实验场地）采集数据：15708927 行
# 🔹 四川省雅安市宝兴县陇东镇滑坡应用示范采集数据：22968910 行
# 🔹 浙江省丽水市庆元县淤上村滑坡应用示范采集数据：8288485 行
# 🔹 浙江省丽水市泰顺县二姑尖滑坡应用示范采集数据：2835652 行
# --------------------------------------------------------------------------------
# 🎯 所有CSV文件的完整真实总行数：53980570
# ================================================================================
